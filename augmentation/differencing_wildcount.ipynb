# %%
#importlibraries

#libraries to extract frame
import os
import pandas as pd
import cv2
import numpy as np
import shutil

#libraries to undergo differencing
import torch
from torchvision import transforms
from PIL import Image
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from torchvision.utils import save_image
from sklearn.decomposition import PCA

#create a function that transforms images to tensors
convert_tensor = transforms.ToTensor()
convert_image = transforms.ToPILImage()

#set directories
#Imgae_to_video_locator_csv
image_to_vid_file = '../../data/Wildcount/location_data/location_dat.csv'

#pest monitoring locater
pest_monitoring_locator = '../../data/Wildcount/location_data/pest_monitoring_images.csv'

#image_to_vid_file = '../../data/Kakadu_fish/location_data/location_dat.csv'
#image_to_vid_file = '../../data/Tassy_BRUV/location_data/location_dat.csv'
#training data location
#folder with images, labels and yaml file are assumed to be within training data folder
training_dat_loc = '../../data/Wildcount/training_data/'
#training_dat_loc = '../../data/Kakadu_fish/training_data/'
#training_dat_loc = '../../data/Tassy_BRUV/training_data/'

#image size (if resizing needed for surrounding images)
image_size = [1920,1080]
#image_size = False
#if you do not want to resize surrounding images replace with False

#pixel location of time_stamp in video if wanted to be removed
#this blacks out top left corner of video to 635 pixels across and 70 down
#if you do not want to remove timestamp replace with False
#time_stamp_loc = [0,70,0,635] 
time_stamp_loc = False 

#whether to read in center frame from surrounding video/images
center_image_surround = True

#directory where differenced images will be saved
diff_folder = '../../data/Wildcount/augmented_images/'
#diff_folder = '../../data/Tassy_BRUV/augmented_images/'

#differenced image folder name
diff_name = 'test'

#differenced parameters
diff = 1
alpha = 10
method = "range"
red_layer = True
do_pca = True
normalise =False
log_im=False
buffer =60

# %%
#images
image_loc = training_dat_loc + 'images/'
#labels
label_loc = training_dat_loc + 'labels/'
#data.yaml directory
yaml_loc =  training_dat_loc + 'data.yaml'
#differencing location
diff_loc = diff_folder + diff_name + '/'


#prepare differenced directory
os.mkdir(diff_loc)
os.mkdir(diff_loc + '/images')
os.mkdir(diff_loc + '/images/train')
os.mkdir(diff_loc + '/images/test')
os.mkdir(diff_loc + '/images/valid')

#shutil.copytree(label_loc,diff_loc + '/labels')
shutil.copy(yaml_loc,diff_loc + '/data.yaml')

#import image location data
val_frame_dat = pd.read_csv(image_to_vid_file)

pest_monitoring_loc_dat = pd.read_csv(pest_monitoring_locator)

# %%
346.9/2 - 32
# Out:
# 141.45

# %%
359 - 346.9/2 - 44.1
# Out:
# 141.45000000000002

# %%
img_folder = list(pest_monitoring_loc_dat['image_name'])
im_index = img_folder.index(val_frame_dat['image_name'][im_num])

# %%
im_list = sorted(os.listdir('../../data/Wildcount/surrounding_images/wildcount/WildCount2017-fullset/Sites 170 to 196/Site 174 Nymboida Far Creek Trail/174C/'))

# %%
im_list
# Out:
# ['174C_2017_Izquierdo_IMG_0001.jpg',
#  '174C_2017_Izquierdo_IMG_0002.jpg',
#  '174C_2017_Izquierdo_IMG_0003.jpg',
#  '174C_2017_Izquierdo_IMG_0004.jpg',
#  '174C_2017_Izquierdo_IMG_0005.jpg',
#  '174C_2017_Izquierdo_IMG_0006.jpg',
#  '174C_2017_Izquierdo_IMG_0007.jpg',
#  '174C_2017_Izquierdo_IMG_0008.jpg',
#  '174C_2017_Izquierdo_IMG_0009.jpg',
#  '174C_2017_Izquierdo_IMG_0010.jpg',
#  '174C_2017_Izquierdo_IMG_0011.jpg',
#  '174C_2017_Izquierdo_IMG_0012.jpg',
#  '174C_2017_Izquierdo_IMG_0013.jpg',
#  '174C_2017_Izquierdo_IMG_0014.jpg',
#  '174C_2017_Izquierdo_IMG_0015.jpg',
#  '174C_2017_Izquierdo_IMG_0016.jpg',
#  '174C_2017_Izquierdo_IMG_0017.jpg',
#  '174C_2017_Izquierdo_IMG_0018.jpg',
#  '174C_2017_Izquierdo_IMG_0019.jpg',
#  '174C_2017_Izquierdo_IMG_0020.jpg',
#  '174C_2017_Izquierdo_IMG_0021.jpg',
#  '174C_2017_Izquierdo_IMG_0022.jpg',
#  '174C_2017_Izquierdo_IMG_0023.jpg',
#  '174C_2017_Izquierdo_IMG_0024.jpg',
#  '174C_2017_Izquierdo_IMG_0025.jpg',
#  '174C_2017_Izquierdo_IMG_0026.jpg',
#  '174C_2017_Izquierdo_IMG_0027.jpg',
#  '174C_2017_Izquierdo_IMG_0028.jpg',
#  '174C_2017_Izquierdo_IMG_0029.jpg',
#  '174C_2017_Izquierdo_IMG_0030.jpg',
#  '174C_2017_Izquierdo_IMG_0031.jpg',
#  '174C_2017_Izquierdo_IMG_0032.jpg',
#  '174C_2017_Izquierdo_IMG_0033.jpg',
#  '174C_2017_Izquierdo_IMG_0034.jpg',
#  '174C_2017_Izquierdo_IMG_0035.jpg',
#  '174C_2017_Izquierdo_IMG_0036.jpg',
#  '174C_2017_Izquierdo_IMG_0037.jpg',
#  '174C_2017_Izquierdo_IMG_0038.jpg',
#  '174C_2017_Izquierdo_IMG_0039.jpg',
#  '174C_2017_Izquierdo_IMG_0040.jpg',
#  '174C_2017_Izquierdo_IMG_0041.jpg',
#  '174C_2017_Izquierdo_IMG_0042.jpg',
#  '174C_2017_Izquierdo_IMG_0043.jpg',
#  '174C_2017_Izquierdo_IMG_0044.jpg',
#  '174C_2017_Izquierdo_IMG_0045.jpg',
#  '174C_2017_Izquierdo_IMG_0046.jpg',
#  '174C_2017_Izquierdo_IMG_0047.jpg',
#  '174C_2017_Izquierdo_IMG_0048.jpg',
#  '174C_2017_Izquierdo_IMG_0049.jpg',
#  '174C_2017_Izquierdo_IMG_0050.jpg',
#  '174C_2017_Izquierdo_IMG_0051.jpg',
#  '174C_2017_Izquierdo_IMG_0052.jpg',
#  '174C_2017_Izquierdo_IMG_0053.jpg',
#  '174C_2017_Izquierdo_IMG_0054.jpg',
#  '174C_2017_Izquierdo_IMG_0055.jpg',
#  '174C_2017_Izquierdo_IMG_0056.jpg',
#  '174C_2017_Izquierdo_IMG_0057.jpg',
#  '174C_2017_Izquierdo_IMG_0058.jpg',
#  '174C_2017_Izquierdo_IMG_0059.jpg',
#  '174C_2017_Izquierdo_IMG_0060.jpg',
#  '174C_2017_Izquierdo_IMG_0061.jpg',
#  '174C_2017_Izquierdo_IMG_0062.jpg',
#  '174C_2017_Izquierdo_IMG_0063.jpg',
#  '174C_2017_Izquierdo_IMG_0064.jpg',
#  '174C_2017_Izquierdo_IMG_0065.jpg',
#  '174C_2017_Izquierdo_IMG_0066.jpg',
#  '174C_2017_Izquierdo_IMG_0067.jpg',
#  '174C_2017_Izquierdo_IMG_0068.jpg',
#  '174C_2017_Izquierdo_IMG_0069.jpg',
#  '174C_2017_Izquierdo_IMG_0070.jpg',
#  '174C_2017_Izquierdo_IMG_0071.jpg',
#  '174C_2017_Izquierdo_IMG_0072.jpg',
#  '174C_2017_Izquierdo_IMG_0073.jpg',
#  '174C_2017_Izquierdo_IMG_0074.jpg',
#  '174C_2017_Izquierdo_IMG_0075.jpg',
#  '174C_2017_Izquierdo_IMG_0076.jpg',
#  '174C_2017_Izquierdo_IMG_0077.jpg',
#  '174C_2017_Izquierdo_IMG_0078.jpg',
#  '174C_2017_Izquierdo_IMG_0079.jpg',
#  '174C_2017_Izquierdo_IMG_0080.jpg',
#  '174C_2017_Izquierdo_IMG_0081.jpg',
#  '174C_2017_Izquierdo_IMG_0082.jpg',
#  '174C_2017_Izquierdo_IMG_0083.jpg',
#  '174C_2017_Izquierdo_IMG_0084.jpg',
#  '174C_2017_Izquierdo_IMG_0085.jpg',
#  '174C_2017_Izquierdo_IMG_0086.jpg',
#  '174C_2017_Izquierdo_IMG_0087.jpg',
#  '174C_2017_Izquierdo_IMG_0088.jpg',
#  '174C_2017_Izquierdo_IMG_0089.jpg',
#  '174C_2017_Izquierdo_IMG_0090.jpg',
#  '174C_2017_Izquierdo_IMG_0091.jpg',
#  '174C_2017_Izquierdo_IMG_0092.jpg',
#  '174C_2017_Izquierdo_IMG_0093.jpg',
#  '174C_2017_Izquierdo_IMG_0094.jpg',
#  '174C_2017_Izquierdo_IMG_0095.jpg',
#  '174C_2017_Izquierdo_IMG_0096.jpg',
#  '174C_2017_Izquierdo_IMG_0097.jpg',
#  '174C_2017_Izquierdo_IMG_0098.jpg',
#  '174C_2017_Izquierdo_IMG_0099.jpg',
#  '174C_2017_Izquierdo_IMG_0100.jpg',
#  '174C_2017_Izquierdo_IMG_0101.jpg',
#  '174C_2017_Izquierdo_IMG_0102.jpg',
#  '174C_2017_Izquierdo_IMG_0103.jpg',
#  '174C_2017_Izquierdo_IMG_0104.jpg',
#  '174C_2017_Izquierdo_IMG_0105.jpg',
#  '174C_2017_Izquierdo_IMG_0106.jpg',
#  '174C_2017_Izquierdo_IMG_0107.jpg',
#  '174C_2017_Izquierdo_IMG_0108.jpg',
#  '174C_2017_Izquierdo_IMG_0109.jpg',
#  '174C_2017_Izquierdo_IMG_0110.jpg',
#  '174C_2017_Izquierdo_IMG_0111.jpg',
#  '174C_2017_Izquierdo_IMG_0112.jpg',
#  '174C_2017_Izquierdo_IMG_0113.jpg',
#  '174C_2017_Izquierdo_IMG_0114.jpg',
#  '174C_2017_Izquierdo_IMG_0115.jpg',
#  '174C_2017_Izquierdo_IMG_0116.jpg',
#  '174C_2017_Izquierdo_IMG_0117.jpg',
#  '174C_2017_Izquierdo_IMG_0118.jpg',
#  '174C_2017_Izquierdo_IMG_0119.jpg',
#  '174C_2017_Izquierdo_IMG_0120.jpg',
#  '174C_2017_Izquierdo_IMG_0121.jpg',
#  '174C_2017_Izquierdo_IMG_0122.jpg',
#  '174C_2017_Izquierdo_IMG_0123.jpg',
#  '174C_2017_Izquierdo_IMG_0124.jpg',
#  '174C_2017_Izquierdo_IMG_0125.jpg',
#  '174C_2017_Izquierdo_IMG_0126.jpg',
#  '174C_2017_Izquierdo_IMG_0127.jpg',
#  '174C_2017_Izquierdo_IMG_0128.jpg',
#  '174C_2017_Izquierdo_IMG_0129.jpg',
#  '174C_2017_Izquierdo_IMG_0130.jpg',
#  '174C_2017_Izquierdo_IMG_0131.jpg',
#  '174C_2017_Izquierdo_IMG_0132.jpg',
#  '174C_2017_Izquierdo_IMG_0133.jpg',
#  '174C_2017_Izquierdo_IMG_0134.jpg',
#  '174C_2017_Izquierdo_IMG_0135.jpg',
#  '174C_2017_Izquierdo_IMG_0136.jpg',
#  '174C_2017_Izquierdo_IMG_0137.jpg',
#  '174C_2017_Izquierdo_IMG_0138.jpg',
#  '174C_2017_Izquierdo_IMG_0139.jpg',
#  '174C_2017_Izquierdo_IMG_0140.jpg',
#  '174C_2017_Izquierdo_IMG_0141.jpg',
#  '174C_2017_Izquierdo_IMG_0142.jpg',
#  '174C_2017_Izquierdo_IMG_0143.jpg',
#  '174C_2017_Izquierdo_IMG_0144.jpg',
#  '174C_2017_Izquierdo_IMG_0145.jpg',
#  '174C_2017_Izquierdo_IMG_0146.jpg',
#  '174C_2017_Izquierdo_IMG_0147.jpg',
#  '174C_2017_Izquierdo_IMG_0148.jpg',
#  '174C_2017_Izquierdo_IMG_0149.jpg',
#  '174C_2017_Izquierdo_IMG_0150.jpg',
#  '174C_2017_Izquierdo_IMG_0151.jpg',
#  '174C_2017_Izquierdo_IMG_0152.jpg',
#  '174C_2017_Izquierdo_IMG_0153.jpg',
#  '174C_2017_Izquierdo_IMG_0154.jpg',
#  '174C_2017_Izquierdo_IMG_0155.jpg',
#  '174C_2017_Izquierdo_IMG_0156.jpg',
#  '174C_2017_Izquierdo_IMG_0157.jpg',
#  '174C_2017_Izquierdo_IMG_0158.jpg',
#  '174C_2017_Izquierdo_IMG_0159.jpg',
#  '174C_2017_Izquierdo_IMG_0160.jpg',
#  '174C_2017_Izquierdo_IMG_0161.jpg',
#  '174C_2017_Izquierdo_IMG_0162.jpg',
#  '174C_2017_Izquierdo_IMG_0163.jpg',
#  '174C_2017_Izquierdo_IMG_0164.jpg',
#  '174C_2017_Izquierdo_IMG_0165.jpg',
#  '174C_2017_Izquierdo_IMG_0166.jpg',
#  '174C_2017_Izquierdo_IMG_0167.jpg',
#  '174C_2017_Izquierdo_IMG_0168.jpg',
#  '174C_2017_Izquierdo_IMG_0169.jpg',
#  '174C_2017_Izquierdo_IMG_0170.jpg',
#  '174C_2017_Izquierdo_IMG_0171.jpg',
#  '174C_2017_Izquierdo_IMG_0172.jpg',
#  '174C_2017_Izquierdo_IMG_0173.jpg',
#  '174C_2017_Izquierdo_IMG_0174.jpg',
#  '174C_2017_Izquierdo_IMG_0175.jpg',
#  '174C_2017_Izquierdo_IMG_0176.jpg',
#  '174C_2017_Izquierdo_IMG_0177.jpg',
#  '174C_2017_Izquierdo_IMG_0178.jpg',
#  '174C_2017_Izquierdo_IMG_0179.jpg',
#  '174C_2017_Izquierdo_IMG_0180.jpg',
#  '174C_2017_Izquierdo_IMG_0181.jpg',
#  '174C_2017_Izquierdo_IMG_0182.jpg',
#  '174C_2017_Izquierdo_IMG_0183.jpg',
#  '174C_2017_Izquierdo_IMG_0184.jpg',
#  '174C_2017_Izquierdo_IMG_0185.jpg',
#  '174C_2017_Izquierdo_IMG_0186.jpg',
#  '174C_2017_Izquierdo_IMG_0187.jpg',
#  '174C_2017_Izquierdo_IMG_0188.jpg',
#  '174C_2017_Izquierdo_IMG_0189.jpg',
#  '174C_2017_Izquierdo_IMG_0190.jpg',
#  '174C_2017_Izquierdo_IMG_0191.jpg',
#  '174C_2017_Izquierdo_IMG_0192.jpg',
#  '174C_2017_Izquierdo_IMG_0193.jpg',
#  '174C_2017_Izquierdo_IMG_0194.jpg',
#  '174C_2017_Izquierdo_IMG_0195.jpg',
#  '174C_2017_Izquierdo_IMG_0196.jpg',
#  '174C_2017_Izquierdo_IMG_0197.jpg',
#  '174C_2017_Izquierdo_IMG_0198.jpg',
#  '174C_2017_Izquierdo_IMG_0199.jpg',
#  '174C_2017_Izquierdo_IMG_0200.jpg',
#  '174C_2017_Izquierdo_IMG_0201.jpg',
#  '174C_2017_Izquierdo_IMG_0202.jpg',
#  '174C_2017_Izquierdo_IMG_0203.jpg',
#  '174C_2017_Izquierdo_IMG_0204.jpg',
#  '174C_2017_Izquierdo_IMG_0205.jpg',
#  '174C_2017_Izquierdo_IMG_0206.jpg',
#  '174C_2017_Izquierdo_IMG_0207.jpg',
#  '174C_2017_Izquierdo_IMG_0208.jpg',
#  '174C_2017_Izquierdo_IMG_0209.jpg',
#  '174C_2017_Izquierdo_IMG_0210.jpg',
#  '174C_2017_Izquierdo_IMG_0211.jpg',
#  '174C_2017_Izquierdo_IMG_0212.jpg',
#  '174C_2017_Izquierdo_IMG_0213.jpg',
#  '174C_2017_Izquierdo_IMG_0214.jpg',
#  '174C_2017_Izquierdo_IMG_0215.jpg',
#  '174C_2017_Izquierdo_IMG_0216.jpg',
#  '174C_2017_Izquierdo_IMG_0217.jpg',
#  '174C_2017_Izquierdo_IMG_0218.jpg',
#  '174C_2017_Izquierdo_IMG_0219.jpg',
#  '174C_2017_Izquierdo_IMG_0220.jpg',
#  '174C_2017_Izquierdo_IMG_0221.jpg',
#  '174C_2017_Izquierdo_IMG_0222.jpg',
#  '174C_2017_Izquierdo_IMG_0223.jpg',
#  '174C_2017_Izquierdo_IMG_0224.jpg',
#  '174C_2017_Izquierdo_IMG_0225.jpg',
#  '174C_2017_Izquierdo_IMG_0226.jpg',
#  '174C_2017_Izquierdo_IMG_0227.jpg',
#  '174C_2017_Izquierdo_IMG_0228.jpg',
#  '174C_2017_Izquierdo_IMG_0229.jpg',
#  '174C_2017_Izquierdo_IMG_0230.jpg',
#  '174C_2017_Izquierdo_IMG_0231.jpg',
#  '174C_2017_Izquierdo_IMG_0232.jpg',
#  '174C_2017_Izquierdo_IMG_0233.jpg',
#  '174C_2017_Izquierdo_IMG_0234.jpg',
#  '174C_2017_Izquierdo_IMG_0235.jpg',
#  '174C_2017_Izquierdo_IMG_0236.jpg',
#  '174C_2017_Izquierdo_IMG_0237.jpg',
#  '174C_2017_Izquierdo_IMG_0238.jpg',
#  '174C_2017_Izquierdo_IMG_0239.jpg',
#  '174C_2017_Izquierdo_IMG_0240.jpg',
#  '174C_2017_Izquierdo_IMG_0241.jpg',
#  '174C_2017_Izquierdo_IMG_0242.jpg',
#  '174C_2017_Izquierdo_IMG_0243.jpg',
#  '174C_2017_Izquierdo_IMG_0244.jpg',
#  '174C_2017_Izquierdo_IMG_0245.jpg',
#  '174C_2017_Izquierdo_IMG_0246.jpg',
#  '174C_2017_Izquierdo_IMG_0247.jpg',
#  '174C_2017_Izquierdo_IMG_0248.jpg',
#  '174C_2017_Izquierdo_IMG_0249.jpg',
#  '174C_2017_Izquierdo_IMG_0250.jpg',
#  '174C_2017_Izquierdo_IMG_0251.jpg',
#  '174C_2017_Izquierdo_IMG_0252.jpg',
#  '174C_2017_Izquierdo_IMG_0253.jpg',
#  '174C_2017_Izquierdo_IMG_0254.jpg',
#  '174C_2017_Izquierdo_IMG_0255.jpg',
#  '174C_2017_Izquierdo_IMG_0256.jpg',
#  '174C_2017_Izquierdo_IMG_0257.jpg',
#  '174C_2017_Izquierdo_IMG_0258.jpg',
#  '174C_2017_Izquierdo_IMG_0259.jpg',
#  '174C_2017_Izquierdo_IMG_0260.jpg',
#  '174C_2017_Izquierdo_IMG_0261.jpg',
#  '174C_2017_Izquierdo_IMG_0262.jpg',
#  '174C_2017_Izquierdo_IMG_0263.jpg',
#  '174C_2017_Izquierdo_IMG_0264.jpg',
#  '174C_2017_Izquierdo_IMG_0265.jpg',
#  '174C_2017_Izquierdo_IMG_0266.jpg',
#  '174C_2017_Izquierdo_IMG_0267.jpg',
#  '174C_2017_Izquierdo_IMG_0268.jpg',
#  '174C_2017_Izquierdo_IMG_0269.jpg',
#  '174C_2017_Izquierdo_IMG_0270.jpg',
#  '174C_2017_Izquierdo_IMG_0271.jpg',
#  '174C_2017_Izquierdo_IMG_0272.jpg',
#  '174C_2017_Izquierdo_IMG_0273.jpg',
#  '174C_2017_Izquierdo_IMG_0274.jpg',
#  '174C_2017_Izquierdo_IMG_0275.jpg',
#  '174C_2017_Izquierdo_IMG_0276.jpg',
#  '174C_2017_Izquierdo_IMG_0277.jpg',
#  '174C_2017_Izquierdo_IMG_0278.jpg',
#  '174C_2017_Izquierdo_IMG_0279.jpg',
#  '174C_2017_Izquierdo_IMG_0280.jpg',
#  '174C_2017_Izquierdo_IMG_0281.jpg',
#  '174C_2017_Izquierdo_IMG_0282.jpg',
#  '174C_2017_Izquierdo_IMG_0283.jpg',
#  '174C_2017_Izquierdo_IMG_0284.jpg',
#  '174C_2017_Izquierdo_IMG_0285.jpg',
#  '174C_2017_Izquierdo_IMG_0286.jpg',
#  '174C_2017_Izquierdo_IMG_0287.jpg',
#  '174C_2017_Izquierdo_IMG_0288.jpg',
#  '174C_2017_Izquierdo_IMG_0289.jpg',
#  '174C_2017_Izquierdo_IMG_0290.jpg',
#  '174C_2017_Izquierdo_IMG_0291.jpg',
#  '174C_2017_Izquierdo_IMG_0292.jpg',
#  '174C_2017_Izquierdo_IMG_0293.jpg',
#  '174C_2017_Izquierdo_IMG_0294.jpg',
#  '174C_2017_Izquierdo_IMG_0295.jpg',
#  '174C_2017_Izquierdo_IMG_0296.jpg',
#  '174C_2017_Izquierdo_IMG_0297.jpg',
#  '174C_2017_Izquierdo_IMG_0298.jpg',
#  '174C_2017_Izquierdo_IMG_0299.jpg',
#  '174C_2017_Izquierdo_IMG_0300.jpg',
#  '174C_2017_Izquierdo_IMG_0301.jpg',
#  '174C_2017_Izquierdo_IMG_0302.jpg',
#  '174C_2017_Izquierdo_IMG_0303.jpg',
#  '174C_2017_Izquierdo_IMG_0304.jpg',
#  '174C_2017_Izquierdo_IMG_0305.jpg',
#  '174C_2017_Izquierdo_IMG_0306.jpg',
#  '174C_2017_Izquierdo_IMG_0307.jpg',
#  '174C_2017_Izquierdo_IMG_0308.jpg',
#  '174C_2017_Izquierdo_IMG_0309.jpg',
#  '174C_2017_Izquierdo_IMG_0310.jpg',
#  '174C_2017_Izquierdo_IMG_0311.jpg',
#  '174C_2017_Izquierdo_IMG_0312.jpg',
#  '174C_2017_Izquierdo_IMG_0313.jpg',
#  '174C_2017_Izquierdo_IMG_0314.jpg',
#  '174C_2017_Izquierdo_IMG_0315.jpg',
#  '174C_2017_Izquierdo_IMG_0316.jpg',
#  '174C_2017_Izquierdo_IMG_0317.jpg',
#  '174C_2017_Izquierdo_IMG_0318.jpg',
#  '174C_2017_Izquierdo_IMG_0319.jpg',
#  '174C_2017_Izquierdo_IMG_0320.jpg',
#  '174C_2017_Izquierdo_IMG_0321.jpg',
#  '174C_2017_Izquierdo_IMG_0322.jpg',
#  '174C_2017_Izquierdo_IMG_0323.jpg',
#  '174C_2017_Izquierdo_IMG_0324.jpg',
#  '174C_2017_Izquierdo_IMG_0325.jpg',
#  '174C_2017_Izquierdo_IMG_0326.jpg',
#  '174C_2017_Izquierdo_IMG_0327.jpg',
#  '174C_2017_Izquierdo_IMG_0328.jpg',
#  '174C_2017_Izquierdo_IMG_0329.jpg',
#  '174C_2017_Izquierdo_IMG_0330.jpg',
#  '174C_2017_Izquierdo_IMG_0331.jpg',
#  '174C_2017_Izquierdo_IMG_0332.jpg',
#  '174C_2017_Izquierdo_IMG_0333.jpg',
#  '174C_2017_Izquierdo_IMG_0334.jpg',
#  '174C_2017_Izquierdo_IMG_0335.jpg',
#  '174C_2017_Izquierdo_IMG_0336.jpg',
#  '174C_2017_Izquierdo_IMG_0337.jpg',
#  '174C_2017_Izquierdo_IMG_0338.jpg',
#  '174C_2017_Izquierdo_IMG_0339.jpg',
#  '174C_2017_Izquierdo_IMG_0340.jpg',
#  '174C_2017_Izquierdo_IMG_0341.jpg',
#  '174C_2017_Izquierdo_IMG_0342.jpg',
#  '174C_2017_Izquierdo_IMG_0343.jpg',
#  '174C_2017_Izquierdo_IMG_0344.jpg',
#  '174C_2017_Izquierdo_IMG_0345.jpg',
#  '174C_2017_Izquierdo_IMG_0346.jpg',
#  '174C_2017_Izquierdo_IMG_0347.jpg',
#  '174C_2017_Izquierdo_IMG_0348.jpg',
#  '174C_2017_Izquierdo_IMG_0349.jpg',
#  '174C_2017_Izquierdo_IMG_0350.jpg',
#  '174C_2017_Izquierdo_IMG_0351.jpg',
#  '174C_2017_Izquierdo_IMG_0352.jpg',
#  '174C_2017_Izquierdo_IMG_0353.jpg',
#  '174C_2017_Izquierdo_IMG_0354.jpg',
#  '174C_2017_Izquierdo_IMG_0355.jpg',
#  '174C_2017_Izquierdo_IMG_0356.jpg',
#  '174C_2017_Izquierdo_IMG_0357.jpg',
#  '174C_2017_Izquierdo_IMG_0358.jpg',
#  '174C_2017_Izquierdo_IMG_0359.jpg',
#  '174C_2017_Izquierdo_IMG_0360.jpg',
#  '174C_2017_Izquierdo_IMG_0361.jpg',
#  '174C_2017_Izquierdo_IMG_0362.jpg',
#  '174C_2017_Izquierdo_IMG_0363.jpg',
#  '174C_2017_Izquierdo_IMG_0364.jpg',
#  '174C_2017_Izquierdo_IMG_0365.jpg',
#  '174C_2017_Izquierdo_IMG_0366.jpg',
#  '174C_2017_Izquierdo_IMG_0367.jpg',
#  '174C_2017_Izquierdo_IMG_0368.jpg',
#  '174C_2017_Izquierdo_IMG_0369.jpg',
#  '174C_2017_Izquierdo_IMG_0370.jpg',
#  '174C_2017_Izquierdo_IMG_0371.jpg',
#  '174C_2017_Izquierdo_IMG_0372.jpg',
#  '174C_2017_Izquierdo_IMG_0373.jpg',
#  '174C_2017_Izquierdo_IMG_0374.jpg',
#  '174C_2017_Izquierdo_IMG_0375.jpg',
#  '174C_2017_Izquierdo_IMG_0376.jpg',
#  '174C_2017_Izquierdo_IMG_0377.jpg',
#  '174C_2017_Izquierdo_IMG_0378.jpg',
#  '174C_2017_Izquierdo_IMG_0379.jpg',
#  '174C_2017_Izquierdo_IMG_0380.jpg',
#  '174C_2017_Izquierdo_IMG_0381.jpg',
#  '174C_2017_Izquierdo_IMG_0382.jpg',
#  '174C_2017_Izquierdo_IMG_0383.jpg',
#  '174C_2017_Izquierdo_IMG_0384.jpg',
#  '174C_2017_Izquierdo_IMG_0385.jpg',
#  '174C_2017_Izquierdo_IMG_0386.jpg',
#  '174C_2017_Izquierdo_IMG_0387.jpg',
#  '174C_2017_Izquierdo_IMG_0388.jpg',
#  '174C_2017_Izquierdo_IMG_0389.jpg',
#  '174C_2017_Izquierdo_IMG_0390.jpg',
#  '174C_2017_Izquierdo_IMG_0391.jpg',
#  '174C_2017_Izquierdo_IMG_0392.jpg',
#  '174C_2017_Izquierdo_IMG_0393.jpg',
#  '174C_2017_Izquierdo_IMG_0394.jpg',
#  '174C_2017_Izquierdo_IMG_0395.jpg',
#  '174C_2017_Izquierdo_IMG_0396.jpg',
#  '174C_2017_Izquierdo_IMG_0397.jpg',
#  '174C_2017_Izquierdo_IMG_0398.jpg',
#  '174C_2017_Izquierdo_IMG_0399.jpg',
#  '174C_2017_Izquierdo_IMG_0400.jpg',
#  '174C_2017_Izquierdo_IMG_0401.jpg',
#  '174C_2017_Izquierdo_IMG_0402.jpg',
#  '174C_2017_Izquierdo_IMG_0403.jpg',
#  '174C_2017_Izquierdo_IMG_0404.jpg',
#  '174C_2017_Izquierdo_IMG_0405.jpg',
#  '174C_2017_Izquierdo_IMG_0406.jpg',
#  '174C_2017_Izquierdo_IMG_0407.jpg',
#  '174C_2017_Izquierdo_IMG_0408.jpg',
#  '174C_2017_Izquierdo_IMG_0409.jpg',
#  '174C_2017_Izquierdo_IMG_0410.jpg',
#  '174C_2017_Izquierdo_IMG_0411.jpg',
#  '174C_2017_Izquierdo_IMG_0412.jpg',
#  '174C_2017_Izquierdo_IMG_0413.jpg',
#  '174C_2017_Izquierdo_IMG_0414.jpg',
#  '174C_2017_Izquierdo_IMG_0415.jpg',
#  '174C_2017_Izquierdo_IMG_0416.jpg',
#  '174C_2017_Izquierdo_IMG_0417.jpg',
#  '174C_2017_Izquierdo_IMG_0418.jpg',
#  '174C_2017_Izquierdo_IMG_0419.jpg',
#  '174C_2017_Izquierdo_IMG_0420.jpg',
#  '174C_2017_Izquierdo_IMG_0421.jpg',
#  '174C_2017_Izquierdo_IMG_0422.jpg',
#  '174C_2017_Izquierdo_IMG_0423.jpg',
#  '174C_2017_Izquierdo_IMG_0424.jpg',
#  '174C_2017_Izquierdo_IMG_0425.jpg',
#  '174C_2017_Izquierdo_IMG_0426.jpg',
#  '174C_2017_Izquierdo_IMG_0427.jpg',
#  '174C_2017_Izquierdo_IMG_0428.jpg',
#  '174C_2017_Izquierdo_IMG_0429.jpg',
#  '174C_2017_Izquierdo_IMG_0430.jpg',
#  '174C_2017_Izquierdo_IMG_0431.jpg',
#  '174C_2017_Izquierdo_IMG_0432.jpg',
#  '174C_2017_Izquierdo_IMG_0433.jpg',
#  '174C_2017_Izquierdo_IMG_0434.jpg',
#  '174C_2017_Izquierdo_IMG_0435.jpg',
#  '174C_2017_Izquierdo_IMG_0436.jpg',
#  '174C_2017_Izquierdo_IMG_0437.jpg',
#  '174C_2017_Izquierdo_IMG_0438.jpg',
#  '174C_2017_Izquierdo_IMG_0439.jpg',
#  '174C_2017_Izquierdo_IMG_0440.jpg',
#  '174C_2017_Izquierdo_IMG_0441.jpg',
#  '174C_2017_Izquierdo_IMG_0442.jpg',
#  '174C_2017_Izquierdo_IMG_0443.jpg',
#  '174C_2017_Izquierdo_IMG_0444.jpg',
#  '174C_2017_Izquierdo_IMG_0445.jpg',
#  '174C_2017_Izquierdo_IMG_0446.jpg',
#  '174C_2017_Izquierdo_IMG_0447.jpg',
#  '174C_2017_Izquierdo_IMG_0448.jpg',
#  '174C_2017_Izquierdo_IMG_0449.jpg',
#  '174C_2017_Izquierdo_IMG_0450.jpg',
#  '174C_2017_Izquierdo_IMG_0451.jpg',
#  '174C_2017_Izquierdo_IMG_0452.jpg',
#  '174C_2017_Izquierdo_IMG_0453.jpg',
#  '174C_2017_Izquierdo_IMG_0454.jpg',
#  '174C_2017_Izquierdo_IMG_0455.jpg',
#  '174C_2017_Izquierdo_IMG_0456.jpg',
#  '174C_2017_Izquierdo_IMG_0457.jpg',
#  '174C_2017_Izquierdo_IMG_0458.jpg',
#  '174C_2017_Izquierdo_IMG_0459.jpg',
#  '174C_2017_Izquierdo_IMG_0460.jpg',
#  '174C_2017_Izquierdo_IMG_0461.jpg',
#  '174C_2017_Izquierdo_IMG_0462.jpg',
#  '174C_2017_Izquierdo_IMG_0463.jpg',
#  '174C_2017_Izquierdo_IMG_0464.jpg',
#  '174C_2017_Izquierdo_IMG_0465.jpg',
#  '174C_2017_Izquierdo_IMG_0466.jpg',
#  '174C_2017_Izquierdo_IMG_0467.jpg',
#  '174C_2017_Izquierdo_IMG_0468.jpg',
#  '174C_2017_Izquierdo_IMG_0469.jpg',
#  '174C_2017_Izquierdo_IMG_0470.jpg',
#  '174C_2017_Izquierdo_IMG_0471.jpg',
#  '174C_2017_Izquierdo_IMG_0472.jpg',
#  '174C_2017_Izquierdo_IMG_0473.jpg',
#  '174C_2017_Izquierdo_IMG_0474.jpg',
#  '174C_2017_Izquierdo_IMG_0475.jpg',
#  '174C_2017_Izquierdo_IMG_0476.jpg',
#  '174C_2017_Izquierdo_IMG_0477.jpg',
#  '174C_2017_Izquierdo_IMG_0478.jpg',
#  '174C_2017_Izquierdo_IMG_0479.jpg',
#  '174C_2017_Izquierdo_IMG_0480.jpg',
#  '174C_2017_Izquierdo_IMG_0481.jpg',
#  '174C_2017_Izquierdo_IMG_0482.jpg',
#  '174C_2017_Izquierdo_IMG_0483.jpg',
#  '174C_2017_Izquierdo_IMG_0484.jpg',
#  '174C_2017_Izquierdo_IMG_0485.jpg',
#  '174C_2017_Izquierdo_IMG_0486.jpg',
#  '174C_2017_Izquierdo_IMG_0487.jpg',
#  '174C_2017_Izquierdo_IMG_0488.jpg',
#  '174C_2017_Izquierdo_IMG_0489.jpg',
#  '174C_2017_Izquierdo_IMG_0490.jpg',
#  '174C_2017_Izquierdo_IMG_0491.jpg',
#  '174C_2017_Izquierdo_IMG_0492.jpg',
#  '174C_2017_Izquierdo_IMG_0493.jpg',
#  '174C_2017_Izquierdo_IMG_0494.jpg',
#  '174C_2017_Izquierdo_IMG_0495.jpg',
#  '174C_2017_Izquierdo_IMG_0496.jpg',
#  '174C_2017_Izquierdo_IMG_0497.jpg',
#  '174C_2017_Izquierdo_IMG_0498.jpg',
#  '174C_2017_Izquierdo_IMG_0499.jpg',
#  '174C_2017_Izquierdo_IMG_0500.jpg',
#  '174C_2017_Izquierdo_IMG_0501.jpg',
#  '174C_2017_Izquierdo_IMG_0502.jpg',
#  '174C_2017_Izquierdo_IMG_0503.jpg',
#  '174C_2017_Izquierdo_IMG_0504.jpg',
#  '174C_2017_Izquierdo_IMG_0505.jpg',
#  '174C_2017_Izquierdo_IMG_0506.jpg',
#  '174C_2017_Izquierdo_IMG_0507.jpg',
#  '174C_2017_Izquierdo_IMG_0508.jpg',
#  '174C_2017_Izquierdo_IMG_0509.jpg',
#  '174C_2017_Izquierdo_IMG_0510.jpg',
#  '174C_2017_Izquierdo_IMG_0511.jpg',
#  '174C_2017_Izquierdo_IMG_0512.jpg',
#  '174C_2017_Izquierdo_IMG_0513.jpg',
#  '174C_2017_Izquierdo_IMG_0514.jpg',
#  '174C_2017_Izquierdo_IMG_0515.jpg',
#  '174C_2017_Izquierdo_IMG_0516.jpg',
#  '174C_2017_Izquierdo_IMG_0517.jpg',
#  '174C_2017_Izquierdo_IMG_0518.jpg',
#  '174C_2017_Izquierdo_IMG_0519.jpg',
#  '174C_2017_Izquierdo_IMG_0520.jpg',
#  '174C_2017_Izquierdo_IMG_0521.jpg',
#  '174C_2017_Izquierdo_IMG_0522.jpg',
#  '174C_2017_Izquierdo_IMG_0523.jpg',
#  '174C_2017_Izquierdo_IMG_0524.jpg',
#  '174C_2017_Izquierdo_IMG_0525.jpg',
#  '174C_2017_Izquierdo_IMG_0526.jpg',
#  '174C_2017_Izquierdo_IMG_0527.jpg',
#  '174C_2017_Izquierdo_IMG_0528.jpg',
#  '174C_2017_Izquierdo_IMG_0529.jpg',
#  '174C_2017_Izquierdo_IMG_0530.jpg',
#  '174C_2017_Izquierdo_IMG_0531.jpg',
#  '174C_2017_Izquierdo_IMG_0532.jpg',
#  '174C_2017_Izquierdo_IMG_0533.jpg',
#  '174C_2017_Izquierdo_IMG_0534.jpg',
#  '174C_2017_Izquierdo_IMG_0535.jpg',
#  '174C_2017_Izquierdo_IMG_0536.jpg',
#  '174C_2017_Izquierdo_IMG_0537.jpg',
#  '174C_2017_Izquierdo_IMG_0538.jpg',
#  '174C_2017_Izquierdo_IMG_0539.jpg',
#  '174C_2017_Izquierdo_IMG_0540.jpg',
#  '174C_2017_Izquierdo_IMG_0541.jpg',
#  '174C_2017_Izquierdo_IMG_0542.jpg',
#  '174C_2017_Izquierdo_IMG_0543.jpg',
#  '174C_2017_Izquierdo_IMG_0544.jpg',
#  '174C_2017_Izquierdo_IMG_0545.jpg',
#  '174C_2017_Izquierdo_IMG_0546.jpg',
#  '174C_2017_Izquierdo_IMG_0547.jpg',
#  '174C_2017_Izquierdo_IMG_0548.jpg',
#  '174C_2017_Izquierdo_IMG_0549.jpg',
#  '174C_2017_Izquierdo_IMG_0550.jpg',
#  '174C_2017_Izquierdo_IMG_0551.jpg',
#  '174C_2017_Izquierdo_IMG_0552.jpg',
#  '174C_2017_Izquierdo_IMG_0553.jpg',
#  '174C_2017_Izquierdo_IMG_0554.jpg',
#  '174C_2017_Izquierdo_IMG_0555.jpg',
#  '174C_2017_Izquierdo_IMG_0556.jpg',
#  '174C_2017_Izquierdo_IMG_0557.jpg',
#  '174C_2017_Izquierdo_IMG_0558.jpg',
#  '174C_2017_Izquierdo_IMG_0559.jpg',
#  '174C_2017_Izquierdo_IMG_0560.jpg',
#  '174C_2017_Izquierdo_IMG_0561.jpg',
#  '174C_2017_Izquierdo_IMG_0562.jpg',
#  '174C_2017_Izquierdo_IMG_0563.jpg',
#  '174C_2017_Izquierdo_IMG_0564.jpg',
#  '174C_2017_Izquierdo_IMG_0565.jpg',
#  '174C_2017_Izquierdo_IMG_0566.jpg',
#  '174C_2017_Izquierdo_IMG_0567.jpg',
#  '174C_2017_Izquierdo_IMG_0568.jpg',
#  '174C_2017_Izquierdo_IMG_0569.jpg',
#  '174C_2017_Izquierdo_IMG_0570.jpg',
#  '174C_2017_Izquierdo_IMG_0571.jpg',
#  '174C_2017_Izquierdo_IMG_0572.jpg',
#  '174C_2017_Izquierdo_IMG_0573.jpg',
#  '174C_2017_Izquierdo_IMG_0574.jpg',
#  '174C_2017_Izquierdo_IMG_0575.jpg',
#  '174C_2017_Izquierdo_IMG_0576.jpg',
#  '174C_2017_Izquierdo_IMG_0577.jpg',
#  '174C_2017_Izquierdo_IMG_0578.jpg',
#  '174C_2017_Izquierdo_IMG_0579.jpg',
#  '174C_2017_Izquierdo_IMG_0580.jpg',
#  '174C_2017_Izquierdo_IMG_0581.jpg',
#  '174C_2017_Izquierdo_IMG_0582.jpg',
#  '174C_2017_Izquierdo_IMG_0583.jpg',
#  '174C_2017_Izquierdo_IMG_0584.jpg',
#  '174C_2017_Izquierdo_IMG_0585.jpg',
#  '174C_2017_Izquierdo_IMG_0586.jpg',
#  '174C_2017_Izquierdo_IMG_0587.jpg',
#  '174C_2017_Izquierdo_IMG_0588.jpg',
#  '174C_2017_Izquierdo_IMG_0589.jpg',
#  '174C_2017_Izquierdo_IMG_0590.jpg',
#  '174C_2017_Izquierdo_IMG_0591.jpg',
#  '174C_2017_Izquierdo_IMG_0592.jpg',
#  '174C_2017_Izquierdo_IMG_0593.jpg',
#  '174C_2017_Izquierdo_IMG_0594.jpg',
#  '174C_2017_Izquierdo_IMG_0595.jpg',
#  '174C_2017_Izquierdo_IMG_0596.jpg',
#  '174C_2017_Izquierdo_IMG_0597.jpg',
#  '174C_2017_Izquierdo_IMG_0598.jpg',
#  '174C_2017_Izquierdo_IMG_0599.jpg',
#  '174C_2017_Izquierdo_IMG_0600.jpg',
#  '174C_2017_Izquierdo_IMG_0601.jpg',
#  '174C_2017_Izquierdo_IMG_0602.jpg',
#  '174C_2017_Izquierdo_IMG_0603.jpg',
#  '174C_2017_Izquierdo_IMG_0604.jpg',
#  '174C_2017_Izquierdo_IMG_0605.jpg',
#  '174C_2017_Izquierdo_IMG_0606.jpg',
#  '174C_2017_Izquierdo_IMG_0607.jpg',
#  '174C_2017_Izquierdo_IMG_0608.jpg',
#  '174C_2017_Izquierdo_IMG_0609.jpg',
#  '174C_2017_Izquierdo_IMG_0610.jpg',
#  '174C_2017_Izquierdo_IMG_0611.jpg',
#  '174C_2017_Izquierdo_IMG_0612.jpg',
#  '174C_2017_Izquierdo_IMG_0613.jpg',
#  '174C_2017_Izquierdo_IMG_0614.jpg',
#  '174C_2017_Izquierdo_IMG_0615.jpg',
#  '174C_2017_Izquierdo_IMG_0616.jpg',
#  '174C_2017_Izquierdo_IMG_0617.jpg',
#  '174C_2017_Izquierdo_IMG_0618.jpg',
#  '174C_2017_Izquierdo_IMG_0619.jpg',
#  '174C_2017_Izquierdo_IMG_0620.jpg',
#  '174C_2017_Izquierdo_IMG_0621.jpg',
#  '174C_2017_Izquierdo_IMG_0622.jpg',
#  '174C_2017_Izquierdo_IMG_0623.jpg',
#  '174C_2017_Izquierdo_IMG_0624.jpg',
#  '174C_2017_Izquierdo_IMG_0625.jpg',
#  '174C_2017_Izquierdo_IMG_0626.jpg',
#  '174C_2017_Izquierdo_IMG_0627.jpg',
#  '174C_2017_Izquierdo_IMG_0628.jpg',
#  '174C_2017_Izquierdo_IMG_0629.jpg',
#  '174C_2017_Izquierdo_IMG_0630.jpg',
#  '174C_2017_Izquierdo_IMG_0631.jpg',
#  '174C_2017_Izquierdo_IMG_0632.jpg',
#  '174C_2017_Izquierdo_IMG_0633.jpg',
#  '174C_2017_Izquierdo_IMG_0634.jpg',
#  '174C_2017_Izquierdo_IMG_0635.jpg',
#  '174C_2017_Izquierdo_IMG_0636.jpg',
#  '174C_2017_Izquierdo_IMG_0637.jpg',
#  '174C_2017_Izquierdo_IMG_0638.jpg',
#  '174C_2017_Izquierdo_IMG_0639.jpg',
#  '174C_2017_Izquierdo_IMG_0640.jpg',
#  '174C_2017_Izquierdo_IMG_0641.jpg',
#  '174C_2017_Izquierdo_IMG_0642.jpg',
#  '174C_2017_Izquierdo_IMG_0643.jpg',
#  '174C_2017_Izquierdo_IMG_0644.jpg',
#  '174C_2017_Izquierdo_IMG_0645.jpg',
#  '174C_2017_Izquierdo_IMG_0646.jpg',
#  '174C_2017_Izquierdo_IMG_0647.jpg',
#  '174C_2017_Izquierdo_IMG_0648.jpg',
#  '174C_2017_Izquierdo_IMG_0649.jpg',
#  '174C_2017_Izquierdo_IMG_0650.jpg',
#  '174C_2017_Izquierdo_IMG_0651.jpg',
#  '174C_2017_Izquierdo_IMG_0652.jpg',
#  '174C_2017_Izquierdo_IMG_0653.jpg',
#  '174C_2017_Izquierdo_IMG_0654.jpg',
#  '174C_2017_Izquierdo_IMG_0655.jpg',
#  '174C_2017_Izquierdo_IMG_0656.jpg',
#  '174C_2017_Izquierdo_IMG_0657.jpg',
#  'Thumbs.db']

# %%
im_num = 36700

#get image folder
if(val_frame_dat['image_folder'][im_num]=='../../data/Wildcount/surrounding_images/pest_monitoring/'):
    img_folder = list(pest_monitoring_loc_dat['image_name'])
else:
    img_folder = sorted(os.listdir(val_frame_dat['image_folder'][im_num]))

#get index in image folder
im_index = img_folder.index(val_frame_dat['image_name'][im_num])

#extract left and right image
left_image_name = img_folder[im_index-1]
left_image = Image.open(val_frame_dat['image_folder'][im_num] + left_image_name)
right_image_name = img_folder[im_index+1]
right_image = Image.open(val_frame_dat['image_folder'][im_num] + right_image_name)

#give conditions if left or right image does not exist
if(left_image_name[:-8]!=val_frame_dat['image_name'][im_num][:-8]):
    left_image = right_image
if(right_image_name[:-8]!=val_frame_dat['image_name'][im_num][:-8]):
    right_image = left_image


#read in center image
if(center_image_surround==True):
    img_center = Image.open(val_frame_dat['image_location'][im_num])
else:
    img_center = Image.open(image_loc + val_frame_dat['split'][im_num] + "/" + val_frame_dat['image_name'][im_num])

#convert images to tensors
img_right_tens_fixed = convert_tensor(right_image)
img_left_tens_fixed = convert_tensor(left_image)
img_center_tens = convert_tensor(img_center)

#fix the left & right image before differencing

if(image_size!=False):    
    img_center_tens = convert_tensor(convert_image(img_center_tens).resize(image_size))
    img_right_tens_fixed = convert_tensor(convert_image(img_right_tens_fixed).resize(image_size))
    img_left_tens_fixed = convert_tensor(convert_image(img_left_tens_fixed).resize(image_size))

#apply three frame differencing
if(method=="abs"):
    diff_im = alpha*(abs(img_center_tens-img_right_tens_fixed) + abs(img_center_tens-img_left_tens_fixed))
elif(method=="var"):
    avg_im = (img_center_tens+img_right_tens_fixed+img_left_tens_fixed)/3
    diff_im_unscaled = ((img_center_tens-avg_im)**2 + (img_right_tens_fixed-avg_im)**2+ (img_left_tens_fixed-avg_im)**2)/2
    diff_im = diff_im_unscaled*(1/torch.max(diff_im_unscaled))*alpha
elif(method=="range"):
    red_i = torch.stack((img_center_tens[0,:,:],img_right_tens_fixed[0,:,:],img_left_tens_fixed[0,:,:]),dim=0)
    green_i = torch.stack((img_center_tens[1,:,:],img_right_tens_fixed[1,:,:],img_left_tens_fixed[1,:,:]),dim=0)
    blue_i = torch.stack((img_center_tens[2,:,:],img_right_tens_fixed[2,:,:],img_left_tens_fixed[2,:,:]),dim=0)

    red_r = torch.max(red_i,dim=0)[0] - torch.min(red_i,dim=0)[0]
    green_r = torch.max(green_i,dim=0)[0] - torch.min(green_i,dim=0)[0]
    blue_r = torch.max(blue_i,dim=0)[0] - torch.min(blue_i,dim=0)[0]

    diff_im = torch.stack((red_r,green_r,blue_r),dim=0)*alpha
elif(method=="naive"):
    diff_im = alpha*(2*img_center_tens-img_right_tens_fixed-img_left_tens_fixed)  + 0.5
else:
    print("Please choose one of 'abs', 'var', 'range' or 'naive' for method.")
    #break
    
if(normalise==True):
    diff_mean = diff_im.mean()
    diff_std = diff_im.std()
    diff_im = (diff_im - diff_mean)/diff_std
else:
    pass
    
if(log_im==True):
    diff_im = np.log(diff_im+1)
else:
    pass

if(red_layer==True):
    diff_im_avg = (diff_im[0,:,:]+diff_im[1,:,:]+diff_im[2,:,:])/3
    if(do_pca==True):
        # Get the image shape
        im_depth, im_height, im_width,  = img_center_tens.shape

        # Reshape the image tensor into a 2D matrix
        im_matrix = np.reshape(convert_image(img_center_tens), (im_height * im_width, im_depth))

        # Perform PCA on the matrix
        pca = PCA(n_components=2,whiten=True)
        reduced_matrix = pca.fit_transform(im_matrix)

        # Reshape the reduced matrix back into a 3D tensor
        reduced_image = convert_tensor(np.reshape(reduced_matrix, (im_height,im_width, 2)))

        #apply sigmoid transform
        reduced_image = torch.sigmoid(reduced_image)
        
        diff_im_final = torch.stack((diff_im_avg,reduced_image[0,:,:],reduced_image[1,:,:]),dim=0)
    else:
        diff_im_final = torch.stack((diff_im_avg,img_center_tens[1,:,:],img_center_tens[2,:,:]),dim=0)
else:
    diff_im_final=diff_im

if(time_stamp_loc!=False):
    diff_im_final[:,time_stamp_loc[0]:time_stamp_loc[1],time_stamp_loc[2]:time_stamp_loc[3]]  = 0    

diff_im_final[:,0:buffer,0:diff_im_final.shape[2]] = 0
diff_im_final[:,diff_im_final.shape[1]-buffer:diff_im_final.shape[1],0:diff_im_final.shape[2]] = 0
        
    #save image
#save_image(diff_im_final,diff_loc +"/images/"+ val_frame_dat['split'][im_num] + "/" + val_frame_dat['image_name'][im_num])
convert_image(diff_im_final)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x2BD01585CD0>

# %%
test_image.shape[2]
# Out:
# 2048

# %%
im_num_list = list(range(0,val_frame_dat.shape[0]))

for im_num in im_num_list:
    #get image folder
    img_folder = os.listdir(val_frame_dat['image_folder'][im_num])

    #get index in image folder
    im_index = img_folder.index(val_frame_dat['image_name'][im_num])

    #extract left and right image
    left_image_name = img_folder[im_index-1]
    left_image = Image.open(val_frame_dat['image_folder'][im_num] + left_image_name)
    right_image_name = img_folder[im_index+1]
    right_image = Image.open(val_frame_dat['image_folder'][im_num] + right_image_name)

    #give conditions if left or right image does not exist
    if(left_image_name[:-7]!=val_frame_dat['image_name'][im_num][:-7]):
        left_image = right_image
    if(right_image_name[:-7]!=val_frame_dat['image_name'][im_num][:-7]):
        right_image = left_image


    #read in center image
    if(center_image_surround==True):
        img_center = Image.open(val_frame_dat['image_location'][im_num])
    else:
        img_center = Image.open(image_loc + val_frame_dat['split'][im_num] + "/" + val_frame_dat['image_name'][im_num])

    #convert images to tensors
    img_right_tens = convert_tensor(right_image)
    img_left_tens = convert_tensor(left_image)
    img_center_tens = convert_tensor(img_center)

    #fix the left & right image before differencing
    if(center_image_surround==True):
        img_center_tens = torch.stack((img_center_tens[2,:,:],img_center_tens[1,:,:],img_center_tens[0,:,:]),dim=0)
        if(image_size!=False):    
            img_center_tens = convert_tensor(convert_image(img_center_tens).resize(image_size))

    img_right_tens_fixed = torch.stack((img_right_tens[2,:,:],img_right_tens[1,:,:],img_right_tens[0,:,:]),dim=0)
    if(image_size!=False):    
        img_right_tens_fixed = convert_tensor(convert_image(img_right_tens_fixed).resize(image_size))
    img_left_tens_fixed = torch.stack((img_left_tens[2,:,:],img_left_tens[1,:,:],img_left_tens[0,:,:]),dim=0)
    if(image_size!=False):     
        img_left_tens_fixed = convert_tensor(convert_image(img_left_tens_fixed).resize(image_size))

    #apply three frame differencing
    if(method=="abs"):
        diff_im = alpha*(abs(img_center_tens-img_right_tens_fixed) + abs(img_center_tens-img_left_tens_fixed))
    elif(method=="var"):
        avg_im = (img_center_tens+img_right_tens_fixed+img_left_tens_fixed)/3
        diff_im_unscaled = ((img_center_tens-avg_im)**2 + (img_right_tens_fixed-avg_im)**2+ (img_left_tens_fixed-avg_im)**2)/2
        diff_im = diff_im_unscaled*(1/torch.max(diff_im_unscaled))*alpha
    elif(method=="range"):
        red_i = torch.stack((img_center_tens[0,:,:],img_right_tens_fixed[0,:,:],img_left_tens_fixed[0,:,:]),dim=0)
        green_i = torch.stack((img_center_tens[1,:,:],img_right_tens_fixed[1,:,:],img_left_tens_fixed[1,:,:]),dim=0)
        blue_i = torch.stack((img_center_tens[2,:,:],img_right_tens_fixed[2,:,:],img_left_tens_fixed[2,:,:]),dim=0)

        red_r = torch.max(red_i,dim=0)[0] - torch.min(red_i,dim=0)[0]
        green_r = torch.max(green_i,dim=0)[0] - torch.min(green_i,dim=0)[0]
        blue_r = torch.max(blue_i,dim=0)[0] - torch.min(blue_i,dim=0)[0]

        diff_im = torch.stack((red_r,green_r,blue_r),dim=0)*alpha
    elif(method=="naive"):
        diff_im = alpha*(2*img_center_tens-img_right_tens_fixed-img_left_tens_fixed)  + 0.5
    else:
        print("Please choose one of 'abs', 'var', 'range' or 'naive' for method.")
        #break
        
    if(normalise==True):
        diff_mean = diff_im.mean()
        diff_std = diff_im.std()
        diff_im = (diff_im - diff_mean)/diff_std
    else:
        pass
        
    if(log_im==True):
        diff_im = np.log(diff_im+1)
    else:
        pass

    if(red_layer==True):
        diff_im_avg = (diff_im[0,:,:]+diff_im[1,:,:]+diff_im[2,:,:])/3
        if(do_pca==True):
            # Get the image shape
            im_depth, im_height, im_width,  = img_center_tens.shape

            # Reshape the image tensor into a 2D matrix
            im_matrix = np.reshape(convert_image(img_center_tens), (im_height * im_width, im_depth))

            # Perform PCA on the matrix
            pca = PCA(n_components=2,whiten=True)
            reduced_matrix = pca.fit_transform(im_matrix)

            # Reshape the reduced matrix back into a 3D tensor
            reduced_image = convert_tensor(np.reshape(reduced_matrix, (im_height,im_width, 2)))

            #apply sigmoid transform
            reduced_image = torch.sigmoid(reduced_image)
            
            diff_im_final = torch.stack((diff_im_avg,reduced_image[0,:,:],reduced_image[1,:,:]),dim=0)
        else:
            diff_im_final = torch.stack((diff_im_avg,img_center_tens[1,:,:],img_center_tens[2,:,:]),dim=0)
    else:
        diff_im_final=diff_im

    if(time_stamp_loc!=False):
        diff_im_final[:,time_stamp_loc[0]:time_stamp_loc[1],time_stamp_loc[2]:time_stamp_loc[3]]  = 0    

            
        #save image
    save_image(diff_im_final,diff_loc +"/images/"+ val_frame_dat['split'][im_num] + "/" + val_frame_dat['image_name'][im_num])
#convert_image(diff_im_final)

# %%
import os
import shutil
import glob

# %%
image_folder = '../../results/Kakadu_fish/result_analysis/valid/combined_attempt_long_diff/'
#image_folder = '../../results/Kakadu_fish/result_analysis/valid/combined_attempt_long_diff/'
#image_folder = '../../results/Kakadu_fish/result_analysis/valid/combined_attempt_long_diff_2/'
save_folder = '../../results/Kakadu_fish/result_analysis/valid/raw_v_diff_alpha_15_diff_10_r_pca_100/'
#save_folder = '../../results/Kakadu_fish/result_analysis/valid/large_diff_long_1/'
#save_folder = '../../results/Kakadu_fish/result_analysis/valid/large_diff_long_2/'

# %%
images = [
22566,
20846,
22807,
41463,
21381,
9283,
28767,
14532,
21285,
30626,
38324,
32565,
23713,
20586,
19910,
21265,
14701,
32247,
43301,
32322,
29216,
23606,
22421,
40071,
28995,
19781,
33702,
16521,
18342,
671,
39070,
15395,
18087,
34691,
36262,
28797,
34373,
4051,
15355,
16665,
35413,
1969,
14536,
16524,
9903,
28562,
4245,
25861,
2660,
43957,
15671,
12825,
12349,
25364,
6322,
3711,
6736,
35811,
43861,
13040,
25033,
2460,
43698,
21957,
25590,
7127,
35617,
42163,
42593,
7666,
22269,
22151,
5351,
18061,
34657,
4039,
31084,
2616,
38538,
40141,
30954,
13774,
7798,
4942,
43551,
38513,
37038,
41730,
31808,
37506,
33665,
35758,
40535,
17578,
8186,
6594,
798,
6902,
36426,
37318
]

# %%
for image in images:
    shutil.copy(image_folder + str(image) + '_joined.jpg',save_folder + str(image) + '.jpg')

# %%
for image in images:
    shutil.copy(image_folder + str(image) + '.jpg',save_folder + str(image) + '.jpg')
